# %% [markdown]
# ![pathfinding.PNG](attachment:pathfinding.PNG)

# %%
import random

class Environment(object):
    def __init__(self):
        self.location = ('1', '2', '3', '4')
        self.move = ('L', 'R', 'U', 'D')
        self.path = {
            '1R': '2', '1L': 'W', '1D': '3', '1U': 'W',
            '2R': 'W', '2L': '1', '2D': '4', '2U': 'W',
            '3R': 'W', '3L': '4', '3D': 'W', '3U': '1',
            '4R': '3', '4L': 'W', '4D': 'W', '4U': '2'
        }
        self.journey = []
        
class Agent(Environment):
    def __init__(self, Environment):
        self.agentLocation = random.choice(Environment.location)
        print('Agent Location', self.agentLocation)
        Environment.journey.append(self.agentLocation[0])
        
        while(self.agentLocation[0] != '4'):
            toMove = self.choosePath(self.agentLocation, Environment)
            self.agentLocation = Environment.path[toMove]
            Environment.journey.append(self.agentLocation[0])
            
            Environment.journey.append('4')
            print('Journey is', Environment.journey)
                
        def choosePath(self, agentLocation, Environment):
            i = random.choice(Environment.move)
            j = str(agentLocatin[0] + i)
            print('Suggested path is', j)
            
            while Environment.path[j] == 'W':
                i = random.choice(Environment.move)
                j = str(agentLocatin[0] + i)
                print('Suggested path is', j)
                
            print('Selected Path', j)
            
            return j
        
e1 = Environment()
a1 = Agent(e1)
# Out:
# Agent Location 2
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1972/2720050432.py in <module>
#      42
#      43 e1 = Environment()
# ---> 44 a1 = Agent(e1)
#      45
#      46
#
# ~\AppData\Local\Temp/ipykernel_1972/2720050432.py in __init__(self, Environment)
#      20
#      21         while(self.agentLocation[0] != '4'):
# ---> 22             toMove = self.choosePath(self.agentLocation, Environment)
#      23             self.agentLocation = Environment.path[toMove]
#      24             Environment.journey.append(self.agentLocation[0])
#
# AttributeError: 'Agent' object has no attribute 'choosePath'
