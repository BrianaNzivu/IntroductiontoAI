# %%
# simple reflex agent
import random


            
class Environment (object):
    def __init__(self):
        self.location = ['A', 'B']
        self.locationCondition = {'A': '0', 
                                  'B': '0'}
        self.vaccumLocation = random.choice(self.location)
        self.locationCondition['A'] = random.randint(0, 1)
        self.locationCondition['B'] = random.randint(0, 1)
        
class Agent (Environment, State):
    def __init__ (self, Environment, State):
        print('The location is', Environment.vaccumLocation)
        print('The condition is', Environment.locationCondition)
        
        count = 0
        while count<2:
            if Environment.locationCondition[Environment.vaccumLocation] == 1:
                Environment.locationCondition[Environment.vaccumLocation] = 0
                print(Environment.vaccumLocation, 'Has been cleaned')
                
            else:
                 print(Environment.vaccumLocation, 'Is clean')
                    
            newIndex = Environment.location.index(Environment.vaccumLocation) + 1
            if newIndex == 2:
                newIndex = 0
            Environment.vaccumLocation = Environment.location[newIndex]
            count += 1
        print('Location Condition', Environment.locationCondition)
        
myEnvironnment = Environment()
myAgent = Agent(myEnvironnment)
# Out:
# The location is B
# The condition is {'A': 1, 'B': 0}
# B Is clean
# A Has been cleaned
# Location Condition {'A': 0, 'B': 0}

# %%
# This is  a model based agent
import random
class Environment (object):
    def __init__(self):
        self.location = ['A', 'B']
        self.locationCondition = {'A': '0', 
                                  'B': '0'}
        self.locationCondition['A'] = random.randint(0, 1)
        self.locationCondition['B'] = random.randint(0, 1)
        
        self.cleaningMethod = {'A': 'L',
                               'B': 'T'}
        
class Agent (Environment):
    def __init__ (self, Environment):
        print('The location is', Environment.vaccumLocation)
        print('The condition is', Environment.locationCondition)
        print('Cleaning mode', Environment.locationCondition)
        
        count = 0
        while count<2:
            if Environment.locationCondition[Environment.vaccumLocation] == 1:
                if Environment.cleaningMethod[Environment.vaccumLocation] == 'T':
                    Environment.cleaningMethod[Environment.vaccumLocation] == 'L'
                else:
                    Environment.cleaningMethod[Environment.vaccumLocation] == 'L'
                    Environment.cleaningMethod[Environment.vaccumLocation] == 'T'

                Environment.locationCondition[Environment.vaccumLocation] = 0
                print(Environment.vaccumLocation, 'Has been cleaned')
                
            else:
                 print(Environment.vaccumLocation, 'Is clean')
                    
            newIndex = Environment.location.index(Environment.vaccumLocation) + 1
            if newIndex == 2:
                newIndex = 0
            Environment.vaccumLocation = Environment.location[newIndex]
            count += 1
        print('Location Condition', Environment.locationCondition)
        print('Cleaning mode', Environment.locationCondition)
        
x = 0
while x<2:
    myEnvironnment = Environment()
    myAgent = Agent(myEnvironnment)
    x += 1
# Out:
# The location is A
# The condition is {'A': 1, 'B': 1}
# Cleaning mode {'A': 1, 'B': 1}
# A Has been cleaned
# B Has been cleaned
# Location Condition {'A': 0, 'B': 0}
# Cleaning mode {'A': 0, 'B': 0}
# The location is A
# The condition is {'A': 1, 'B': 1}
# Cleaning mode {'A': 1, 'B': 1}
# A Has been cleaned
# B Has been cleaned
# Location Condition {'A': 0, 'B': 0}
# Cleaning mode {'A': 0, 'B': 0}

# %%
# Adding Memory
import random

class State(object):
    def __init__(self):
        self.cleaningMethod = {'A':'L','B':'T'}
        self.cleaningMethod ['A'] = random.choice(['L', 'T'])
        self.cleaningMethod['B'] = random.choice(['L', 'T'])
            
class Environment (object):
    def __init__(self):
        self.location = ['A', 'B']
        self.locationCondition = {'A': '0', 
                                  'B': '0'}
        self.vaccumLocation = random.choice(self.location)
        self.locationCondition['A'] = random.randint(0, 1)
        self.locationCondition['B'] = random.randint(0, 1)
#         self.cleaningMethod = {'A': 'L',
#                                'B': 'T'}
        
class Agent (Environment, State):
    def __init__ (self, Environment, State):
        print('The location is', Environment.vaccumLocation)
        print('The condition is', Environment.locationCondition)
        print('Cleaning mode', State.cleaningMethod)
        
        count = 0
        
        while count<2:
            if Environment.locationCondition[Environment.vaccumLocation] == 1:
                if Environment.cleaningMethod[Environment.vaccumLocation] == 'T':
                    Environment.cleaningMethod[Environment.vaccumLocation] == 'L'
                else:
                    Environment.cleaningMethod[Environment.vaccumLocation] == 'L'
                    Environment.cleaningMethod[Environment.vaccumLocation] == 'T'

                Environment.locationCondition[Environment.vaccumLocation] = 0
                print(Environment.vaccumLocation, 'Has been cleaned')
                
            else:
                 print(Environment.vaccumLocation, 'Is clean')
                    
            newIndex = Environment.location.index(Environment.vaccumLocation) + 1
            if newIndex == 2:
                newIndex = 0
            Environment.vaccumLocation = Environment.location[newIndex]
            count += 1
        print('Location Condition', Environment.locationCondition)
        print('Cleaning mode', Environment.locationCondition)

theState = State()
x = 0
while x<2:
    myEnvironnment = Environment()
    myAgent = Agent(myEnvironnment, State)
    x += 1
# Out:
# The location is B
# The condition is {'A': 0, 'B': 0}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 55
#      53 while x<2:
#      54     myEnvironnment = Environment()
# ---> 55     myAgent = Agent(myEnvironnment, State)
#      56     x += 1
#
# Cell In[1], line 25, in Agent.__init__(self, Environment, State)
#      23 print('The location is', Environment.vaccumLocation)
#      24 print('The condition is', Environment.locationCondition)
# ---> 25 print('Cleaning mode', State.cleaningMethod)
#      27 count = 0
#      29 while count<2:
#
# AttributeError: type object 'State' has no attribute 'cleaningMethod'

# %%
# Adding Four Locations
import random

class State(object):
    def __init__(self):
        self.cleaningMethod = {'A':'L','B':'T', 'C':'L', 'D':'T'}
        self.cleaningMethod ['A'] = random.choice(['L', 'T'])
        self.cleaningMethod['B'] = random.choice(['L', 'T'])
        self.cleaningMethod['C'] = random.choice(['L', 'T'])
        self.cleaningMethod['D'] = random.choice(['L', 'T'])       

            
class Environment (object):
    def __init__(self):
        self.location = ['A', 'B', 'C', 'D']
        self.locationCondition = {'A': '0', 
                                  'B': '0',
                                  'C':'0',
                                  'D':'0'}
        self.vaccumLocation = random.choice(self.location)
        self.locationCondition['A'] = random.randint(0, 1)
        self.locationCondition['B'] = random.randint(0, 1)
        self.locationCondition['C'] = random.randint(0, 1)
        self.locationCondition['D'] = random.randint(0, 1)

        
class Agent (Environment, State):
    def __init__ (self, Environment, State):
        print('The location is', Environment.vaccumLocation)
        print('The condition is', Environment.locationCondition)
        print('Cleaning mode', State.cleaningMethod)
        
        count = 0
        
        while count<2:
            if Environment.locationCondition[Environment.vaccumLocation] == 1:
                if Environment.cleaningMethod[Environment.vaccumLocation] == 'T':
                    Environment.cleaningMethod[Environment.vaccumLocation] == 'L'
                else:
                    Environment.cleaningMethod[Environment.vaccumLocation] == 'L'
                    Environment.cleaningMethod[Environment.vaccumLocation] == 'T'

                Environment.locationCondition[Environment.vaccumLocation] = 0
                print(Environment.vaccumLocation, 'Has been cleaned')
                
            else:
                 print(Environment.vaccumLocation, 'Is clean')
                    
            newIndex = Environment.location.index(Environment.vaccumLocation) + 1
            if newIndex == 2:
                newIndex = 0
            Evironment.vaccumLocation = Environment.location[newIndex]
            count += 1
        print('Location Condition', Environment.locationCondition)
        print('Cleaning mode', Environment.locationCondition)

theState = State()
x = 0
while x<2:
    myEnvironnment = Environment()
    myAgent = Agent(myEnvironnment, State)
    x += 1
# Out:
# The location is A
# The condition is {'A': 0, 'B': 1, 'C': 1, 'D': 0}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 61
#      59 while x<2:
#      60     myEnvironnment = Environment()
# ---> 61     myAgent = Agent(myEnvironnment, State)
#      62     x += 1
#
# Cell In[2], line 31, in Agent.__init__(self, Environment, State)
#      29 print('The location is', Environment.vaccumLocation)
#      30 print('The condition is', Environment.locationCondition)
# ---> 31 print('Cleaning mode', State.cleaningMethod)
#      33 count = 0
#      35 while count<2:
#
# AttributeError: type object 'State' has no attribute 'cleaningMethod'

# %%
# Adding Four Locations sensitive to time
import random
import time

class State(object):
    def __init__(self):
        self.cleaningMethod = {'A':'L','B':'T', 'C':'L', 'D':'T'}
        self.cleaningMethod ['A'] = random.choice(['L', 'T'])
        self.cleaningMethod['B'] = random.choice(['L', 'T'])
        self.cleaningMethod['C'] = random.choice(['L', 'T'])
        self.cleaningMethod['D'] = random.choice(['L', 'T'])
            
class Environment (object):
    def __init__(self):
        self.location = ['A', 'B', 'C', 'D']
        self.locationCondition = {'A': '0', 
                                  'B': '0',
                                  'C':'0',
                                  'D':'0'}
        self.vaccumLocation = random.choice(self.location)
        self.locationCondition['A'] = random.randint(0, 1)
        self.locationCondition['B'] = random.randint(0, 1)
        self.locationCondition['C'] = random.randint(0, 1)
        self.locationCondition['D'] = random.randint(0, 1)
#         self.cleaningMethod = {'A': 'L',
#                                'B': 'T'}
        
class Agent (Environment, State):
    def __init__ (self, Environment, State):
        print('The location is', Environment.vaccumLocation)
        print('The condition is', Environment.locationCondition)
        print('Cleaning mode', State.cleaningMethod)
        
        count = 0
        
        while count<2:
            if Environment.locationCondition[Environment.vaccumLocation] == 1:
                if Environment.cleaningMethod[Environment.vaccumLocation] == 'T':
                    Environment.cleaningMethod[Environment.vaccumLocation] == 'L'
                else:
                    Environment.cleaningMethod[Environment.vaccumLocation] == 'L'
                    Environment.cleaningMethod[Environment.vaccumLocation] == 'T'

                Environment.locationCondition[Environment.vaccumLocation] = 0
                print(Environment.vaccumLocation, 'Has been cleaned')
                
            else:
                 print(Environment.vaccumLocation, 'Is clean')
                    
            newIndex = Environment.location.index(Environment.vaccumLocation) + 1
            if newIndex == 2:
                newIndex = 0
            Environment.vaccumLocation = Environment.location[newIndex]
            count += 1
        print('Location Condition', Environment.locationCondition)
        print('Cleaning mode', Environment.locationCondition)

theState = State()
x = 0
while x<12:
    myEnvironnment = Environment()
    myAgent = Agent(myEnvironnment, theState)
    x += 1
    time.sleep(5) #I hour of snooze
# Out:
# The location is C
# The condition is {'A': 1, 'B': 0, 'C': 0, 'D': 0}
# Cleaning mode {'A': 'T', 'B': 'L', 'C': 'L', 'D': 'L'}
# C Is clean
# D Is clean
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3592/64688280.py in <module>
#      60 while x<12:
#      61     myEnvironnment = Environment()
# ---> 62     myAgent = Agent(myEnvironnment, theState)
#      63     x += 1
#      64     time.sleep(5) #I hour of snooze
#
# ~\AppData\Local\Temp/ipykernel_3592/64688280.py in __init__(self, Environment, State)
#      51             if newIndex == 2:
#      52                 newIndex = 0
# ---> 53             Environment.vaccumLocation = Environment.location[newIndex]
#      54             count += 1
#      55         print('Location Condition', Environment.locationCondition)
#
# IndexError: list index out of range

# %%
# Adding Four Locations sensitive to time
import random
import time

class Performance(object):
    def __init__(self):
        self.Score = 0
    
    def DisplayScore(self):
        print('Score', self.Score)
        
        performance = (self.Score/48) * 100
        print('Perfprmance', P, '%')
class State(object):
    def __init__(self):
        self.cleaningMethod = {'A':'L','B':'T', 'C':'L', 'D':'T'}
        self.cleaningMethod ['A'] = random.choice(['L', 'T'])
        self.cleaningMethod['B'] = random.choice(['L', 'T'])
        self.cleaningMethod['C'] = random.choice(['L', 'T'])
        self.cleaningMethod['D'] = random.choice(['L', 'T'])
            
class Environment (object):
    def __init__(self):
        self.location = ['A', 'B', 'C', 'D']
        self.locationCondition = { 'A': '0', 'B': '0', 'C':'0', 'D':'0'}
        
        self.vaccumLocation = random.choice(self.location)
        self.locationCondition['A'] = random.randint(0, 1)
        self.locationCondition['B'] = random.randint(0, 1)
        self.locationCondition['C'] = random.randint(0, 1)
        self.locationCondition['D'] = random.randint(0, 1)
#         self.cleaningMethod = {'A': 'L',
#                                'B': 'T'}
        
class Agent (Environment, State, Performance):
    def __init__ (self, Environment, State, Performance):
        print('The location is', Environment.vaccumLocation)
        print('The condition is', Environment.locationCondition)
        print('Cleaning mode', State.cleaningMethod)
        
        count = 0
        
        while count<2:
            if Environment.locationCondition[Environment.vaccumLocation] == 1:
                Performance.Score + 1
                if Environment.cleaningMethod[Environment.vaccumLocation] == 'T':
                    Environment.cleaningMethod[Environment.vaccumLocation] == 'L'
                else:
                    Environment.cleaningMethod[Environment.vaccumLocation] == 'L'
                    Environment.cleaningMethod[Environment.vaccumLocation] == 'T'

                Environment.locationCondition[Environment.vaccumLocation] = 0
                print(Environment.vaccumLocation, 'Has been cleaned')
                
            else:
                 print(Environment.vaccumLocation, 'Is clean')
                    
            newIndex = Environment.location.index(Environment.vaccumLocation) + 1
            if newIndex == 2:
                newIndex = 0
            Environment.vaccumLocation = Environment.location[newIndex]
            count += 1
        print('Location Condition', Environment.locationCondition)
        print('Cleaning mode', Environment.locationCondition)

theState = State()
thePerformance = Performance()
x = 0
while x<12:
    myEnvironnment = Environment()
    myAgent = Agent(myEnvironnment, theState, thePerformance)
    x += 1
    time.sleep(5) #I hour of snooze
thePerformance.DisplayScore()
# Out:
# The location is C
# The condition is {'A': 1, 'B': 1, 'C': 1, 'D': 0}
# Cleaning mode {'A': 'L', 'B': 'L', 'C': 'L', 'D': 'L'}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3592/1100876391.py in <module>
#      69 while x<12:
#      70     myEnvironnment = Environment()
# ---> 71     myAgent = Agent(myEnvironnment, theState, thePerformance)
#      72     x += 1
#      73     time.sleep(5) #I hour of snooze
#
# ~\AppData\Local\Temp/ipykernel_3592/1100876391.py in __init__(self, Environment, State, Performance)
#      44             if Environment.locationCondition[Environment.vaccumLocation] == 1:
#      45                 Performance.Score + 1
# ---> 46                 if Environment.cleaningMethod[Environment.vaccumLocation] == 'T':
#      47                     Environment.cleaningMethod[Environment.vaccumLocation] == 'L'
#      48                 else:
#
# AttributeError: 'Environment' object has no attribute 'cleaningMethod'

# %%
# Adding Four Locations sensitive to time
import random
import time

class Performance(object):
    def __init__(self):
        self.Score = 0
        self.Visit = 0
    
    def DisplayScore(self):
        print('Score', self.Score)
        performance = (self.Score/self.) * 100
        print('Performance', P, '%')
        return performance
        
class State(object):
    def __init__(self):
        self.cleaningMethod = {'A':'L','B':'T', 'C':'L', 'D':'T'}
        self.cleaningMethod ['A'] = random.choice(['L', 'T'])
        self.cleaningMethod['B'] = random.choice(['L', 'T'])
        self.cleaningMethod['C'] = random.choice(['L', 'T'])
        self.cleaningMethod['D'] = random.choice(['L', 'T'])
            
class Environment (object):
    def __init__(self):
        self.location = ['A', 'B', 'C', 'D']
        self.locationCondition = { 'A': '0', 'B': '0', 'C':'0', 'D':'0'}
        
        self.vaccumLocation = random.choice(self.location)
        self.locationCondition['A'] = random.randint(0, 1)
        self.locationCondition['B'] = random.randint(0, 1)
        self.locationCondition['C'] = random.randint(0, 1)
        self.locationCondition['D'] = random.randint(0, 1)
#         self.cleaningMethod = {'A': 'L',
#                                'B': 'T'}
        
class Agent (Environment, State, Performance):
    def __init__ (self, Environment, State, Performance):
        print('The location is', Environment.vaccumLocation)
        print('The condition is', Environment.locationCondition)
        print('Cleaning mode', State.cleaningMethod)
        
        count = 0
        
        while count<4:
            Performance.visit
            if Environment.locationCondition[Environment.vaccumLocation] == 1:
                Performance.Score + 1
                if Environment.cleaningMethod[Environment.vaccumLocation] == 'T':
                    Environment.cleaningMethod[Environment.vaccumLocation] == 'L'
                else:
                    Environment.cleaningMethod[Environment.vaccumLocation] == 'L'
                    Environment.cleaningMethod[Environment.vaccumLocation] == 'T'

                Environment.locationCondition[Environment.vaccumLocation] = 0
                print(Environment.vaccumLocation, 'Has been cleaned')
                
            else:
                 print(Environment.vaccumLocation, 'Is clean')
                    
            newIndex = Environment.location.index(Environment.vaccumLocation) + 1
            if newIndex == 2:
                newIndex = 0
            Environment.vaccumLocation = Environment.location[newIndex]
            count += 1
        print('Location Condition', Environment.locationCondition)
        print('Cleaning mode', Environment.locationCondition)

theState = State()
thePerformance = Performance()
x = 0
timeInterval = 2
while x<12:
    myEnvironnment = Environment()
    myAgent = Agent(myEnvironnment, theState, thePerformance)
    if x == 5:
        performance = thePerformance.DisplayScore()
        if p>50:
            print(performance, 'Increasing cleaning cycle')
            timeInterval = 1
            x = 0
        else:
            print(performance, 'Reducing cleaning cycles')
            timeInterval = 3
            x = x + 3
        
    x += 1
    time.sleep(timeInterval) #I hour of snooze
thePerformance.DisplayScore()
# Out:
# The location is A
# The condition is {'A': 0, 'B': 0, 'C': 1, 'D': 1}
# Cleaning mode {'A': 'L', 'B': 'L', 'C': 'L', 'D': 'T'}
# A Is clean
# B Is clean
# Location Condition {'A': 0, 'B': 0, 'C': 1, 'D': 1}
# Cleaning mode {'A': 0, 'B': 0, 'C': 1, 'D': 1}
# The location is D
# The condition is {'A': 0, 'B': 0, 'C': 0, 'D': 0}
# Cleaning mode {'A': 'L', 'B': 'L', 'C': 'L', 'D': 'T'}
# D Is clean
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3592/270172581.py in <module>
#      71 while x<12:
#      72     myEnvironnment = Environment()
# ---> 73     myAgent = Agent(myEnvironnment, theState, thePerformance)
#      74     if x == 5:
#      75         performance = thePerformance.DisplayScore()
#
# ~\AppData\Local\Temp/ipykernel_3592/270172581.py in __init__(self, Environment, State, Performance)
#      60             if newIndex == 2:
#      61                 newIndex = 0
# ---> 62             Environment.vaccumLocation = Environment.location[newIndex]
#      63             count += 1
#      64         print('Location Condition', Environment.locationCondition)
#
# IndexError: list index out of range

# %%
# This is  a model based agent
import random
class Environment (object):
    def __init__(self):
        self.location = ['A', 'B']
        self.locationCondition = {'A': '0', 
                                  'B': '0'}
        self.locationCondition['A'] = random.randint(0, 1)
        self.locationCondition['B'] = random.randint(0, 1)
        
        self.cleaningMethod = {'A': 'L',
                               'B': 'T'}
        
class Agent (Environment):
    def __init__ (self, Environment):
        print('The location is', Environment.vaccumLocation)
        print('The condition is', Environment.locationCondition)
        print('Cleaning mode', Environment.locationCondition)
        
        count = 0
        while count<2:
            if Environment.locationCondition[Environment.vaccumLocation] == 1:
                if Environment.cleaningMethod[Environment.vaccumLocation] == 'T':
                    Environment.cleaningMethod[Environment.vaccumLocation] == 'L'
                else:
                    Environment.cleaningMethod[Environment.vaccumLocation] == 'L'
                    Environment.cleaningMethod[Environment.vaccumLocation] == 'T'

                Environment.locationCondition[Environment.vaccumLocation] = 0
                print(Environment.vaccumLocation, 'Has been cleaned')
                
            else:
                 print(Environment.vaccumLocation, 'Is clean')
                    
            newIndex = Environment.location.index(Environment.vaccumLocation) + 1
            if newIndex == 2:
                newIndex = 0
            Environment.vaccumLocation = Environment.location[newIndex]
            count += 1
        print('Location Condition', Environment.locationCondition)
        print('Cleaning mode', Environment.locationCondition)
        
x = 0
while x<2:
    myEnvironnment = Environment()
    myAgent = Agent(myEnvironnment)
    x += 1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 46
#      44 while x<2:
#      45     myEnvironnment = Environment()
# ---> 46     myAgent = Agent(myEnvironnment)
#      47     x += 1
#
# Cell In[3], line 16, in Agent.__init__(self, Environment)
#      15 def __init__ (self, Environment):
# ---> 16     print('The location is', Environment.vaccumLocation)
#      17     print('The condition is', Environment.locationCondition)
#      18     print('Cleaning mode', Environment.locationCondition)
#
# AttributeError: 'Environment' object has no attribute 'vaccumLocation'
